# %%
# %load_ext autoreload
# %autoreload 2
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append("..")
from data import gen_data
import utils.visualization
from train import test_single_data
from model.simple_GINA import simple_GINA
import seaborn as sns
from matplotlib import transforms
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
padding_length = 0
G = gen_data.DataGenerator(1, 2, 128,padding_length=padding_length)
G.addPeakShape(["triangle", "square"])
X, Y = G.generate(noisy_peak_num=[2,2])
print(X.shape)
#model = simple_GINA(X.shape[2]).double().cuda()
#model.load_state_dict(torch.load("model_weight.pkl"))

#predict, attention = test_single_data(model, X, Y)
#print(attention.size())
# Out:
# (1, 2, 128)

# %%
visualization.draw(X[0][0], X[0][1], np.random.normal(0.5, 0.2, (128, 128))).show()
# Out:
# 

# %%
visualization.atten_heatmap(X[0][0], X[0][1], atten)
